# %%
df = spark.read.table("rsa_cata.bronze.regions")
df.display()

# %%
df.write.format("delta")\
    .mode("append")\
    .save("abfss://silver@retailsalesanalysissanil.dfs.core.windows.net/regions")

# %% [markdown]
# ### **Table Creation to top of the Data**

# %%
# %sql
create table if not exists rsa_cata.silver.regions_silver
using delta
location 'abfss://silver@retailsalesanalysissanil.dfs.core.windows.net/regions'
